# %% [markdown]
# Data Usage

# %%
# %load_ext autoreload
# %autoreload 2

import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, os.path.join(parent_dir)) 

from shapely.geometry import Point

import numpy as np
from topo2vec.datasets.random_dataset import RandomDataset
from topo2vec.datasets.classification_dataset import ClassificationDataset
from topo2vec.common.visualizations import plot_n_np_arrays
from topo2vec.CONSTANTS import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
'''dataset = RandomDataset(16, [5])
print('data of the different points')
images = [obj[0].squeeze() for obj in dataset]
plot_n_np_arrays(images, lines_number = 4)'''

dataset = ClassificationDataset(radii = [10], first_class_path = N49_E05_STREAMS,
                                        first_class_label = 'stream', outer_polygon=None)
print('data of stream the different points')
images = random.choice([obj[0].squeeze() for obj in dataset], 16)
plot_n_np_arrays(images, lines_number = 4)
# Out:
# .geojson
# data of stream the different points
